# %%
import pandas as pd

# %%
df = pd.read_csv('Netflix Userbase.csv')

# %%
df.head()
#diplays top 5 columns of dataset
# Out:
#    User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 0        1             Basic               10  15-01-22          10-06-23
# 1        2           Premium               15  05-09-21          22-06-23
# 2        3          Standard               12  28-02-23          27-06-23
# 3        4          Standard               12  10-07-22          26-06-23
# 4        5             Basic               10  01-05-23          28-06-23
#
#           Country  Age  Gender      Device Plan Duration
# 0   United States   28    Male  Smartphone       1 Month
# 1          Canada   35  Female      Tablet       1 Month
# 2  United Kingdom   42    Male    Smart TV       1 Month
# 3       Australia   51  Female      Laptop       1 Month
# 4         Germany   33    Male  Smartphone       1 Month

# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df.tail()
# dispaly last 5 columns in dataset
# Out:
#       User ID Subscription Type  Monthly Revenue Join Date Last Payment Date  \
# 2495     2496           Premium               14  25-07-22          12-07-23
# 2496     2497             Basic               15  04-08-22          14-07-23
# 2497     2498          Standard               12  09-08-22          15-07-23
# 2498     2499          Standard               13  12-08-22          12-07-23
# 2499     2500             Basic               15  13-08-22          12-07-23
#
#             Country  Age  Gender    Device Plan Duration
# 2495          Spain   28  Female  Smart TV       1 Month
# 2496          Spain   33  Female  Smart TV       1 Month
# 2497  United States   38    Male    Laptop       1 Month
# 2498         Canada   48  Female    Tablet       1 Month
# 2499  United States   35  Female  Smart TV       1 Month

# %%
df.shape
# to show the count of no of rows and columns in dataset
# Out:
# (2500, 10)

# %%
df.columns
# display the column names available in the dataset
# Out:
# Index(['User ID', 'Subscription Type', 'Monthly Revenue', 'Join Date',
#        'Last Payment Date', 'Country', 'Age', 'Gender', 'Device',
#        'Plan Duration'],
#       dtype='object')

# %%
df.dtypes
#display the datatype of each feature
# Out:
# User ID               int64
# Subscription Type    object
# Monthly Revenue       int64
# Join Date            object
# Last Payment Date    object
# Country              object
# Age                   int64
# Gender               object
# Device               object
# Plan Duration        object
# dtype: object

# %%
df["Country"].unique()
#display unique column in specific column
# Out:
# array(['United States', 'Canada', 'United Kingdom', 'Australia',
#        'Germany', 'France', 'Brazil', 'Mexico', 'Spain', 'Italy'],
#       dtype=object)

# %%
df["Country"].nunique()
# Out:
# 10

# %%
df["Device"].unique()
# Out:
# array(['Smartphone', 'Tablet', 'Smart TV', 'Laptop'], dtype=object)

# %%
df["Subscription Type"].unique()
# Out:
# array(['Basic', 'Premium', 'Standard'], dtype=object)

# %%
df.nunique()
# Out:
# User ID              2500
# Subscription Type       3
# Monthly Revenue         6
# Join Date             300
# Last Payment Date      26
# Country                10
# Age                    26
# Gender                  2
# Device                  4
# Plan Duration           1
# dtype: int64

# %%
df.describe()
# Out:
#           User ID  Monthly Revenue          Age
# count  2500.00000      2500.000000  2500.000000
# mean   1250.50000        12.508400    38.795600
# std     721.83216         1.686851     7.171778
# min       1.00000        10.000000    26.000000
# 25%     625.75000        11.000000    32.000000
# 50%    1250.50000        12.000000    39.000000
# 75%    1875.25000        14.000000    45.000000
# max    2500.00000        15.000000    51.000000

# %%
# display the no of times it repeated in a row
df["Country"].value_counts()
# Out:
# Country
# United States     451
# Spain             451
# Canada            317
# United Kingdom    183
# Australia         183
# Germany           183
# France            183
# Brazil            183
# Mexico            183
# Italy             183
# Name: count, dtype: int64

# %%
df.isnull()
# Out:
#       User ID  Subscription Type  Monthly Revenue  Join Date  \
# 0       False              False            False      False
# 1       False              False            False      False
# 2       False              False            False      False
# 3       False              False            False      False
# 4       False              False            False      False
# ...       ...                ...              ...        ...
# 2495    False              False            False      False
# 2496    False              False            False      False
# 2497    False              False            False      False
# 2498    False              False            False      False
# 2499    False              False            False      False
#
#       Last Payment Date  Country    Age  Gender  Device  Plan Duration
# 0                 False    False  False   False   False          False
# 1                 False    False  False   False   False          False
# ...

# %%
sns.heatmap(df.isnull())
# Out:
# <Axes: >

# %%
import pandas as pd
df["Join Date"] = pd.to_datetime(df["Join Date"])

df["Last Payment Date"] = pd.to_datetime(df["Last Payment Date"])
# to change from oject to a datetime format
print(df)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_4324\909235755.py:2: UserWarning: Could not infer format, so each element will be parsed individually, falling back to `dateutil`. To ensure parsing is consistent and as-expected, please specify a format.
#   df["Join Date"] = pd.to_datetime(df["Join Date"])
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15        2023-10-06
# 1           2           Premium               15 2021-05-09        2023-06-22
# 2           3          Standard               12 2023-02-28        2023-06-27
# 3           4          Standard               12 2022-10-07        2023-06-26
# 4           5             Basic               10 2023-01-05        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25        2023-12-07
# ...

# %%
plt.figure(figsize= (4, 3))
sns.countplot(data=df,x='Gender')
plt.xlabel=("Gender")
plt.ylabel=("Distribution")
plt.title("Distribution of Gender")
plt.show()

# %%
plt.figure(figsize=(10,4))
sns.countplot(data=df, x="Gender", hue = "Country")
plt.xlabel=('Gender')
plt.ylabel=('Country')
plt.title('Gender vise country subscribers')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 plt.figure(figsize=(10,4))
#       2 sns.countplot(data=df, x="Gender", hue = "Country")
#       3 plt.xlabel=('Gender')
#
# NameError: name 'plt' is not defined

# %%
plt.figure(figsize=(12,9))
sns.countplot(data=df, x="Country", hue = "Device")
plt.xlabel=('Country')
plt.ylabel=('Device')
plt.title('device used in different countries')
plt.show()

# %%
#DataVisualization #Insights #Analytics Group the data by Feedback and calculate the count of each category
Device =  df.groupby('Device').size()
#Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(Device, labels = Device.index, shadow=True,autopct='%1.1f%%', startangle=148) 
plt.title('Distribution_of_Device')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle. 
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x="Subscription Type")
plt.xlabel=('Subscription Type')
plt.ylabel=('Counts')
plt.title('Distribution of subscription Type')
plt.show()

# %%
plt.figure(figsize=(7,3))
sns.countplot(data=df, x="Country")
plt.xlabel=('Country')
plt.ylabel=('Counts')
plt.title('country vise users')
plt.show()

# %%
df
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15        2023-10-06
# 1           2           Premium               15 2021-05-09        2023-06-22
# 2           3          Standard               12 2023-02-28        2023-06-27
# 3           4          Standard               12 2022-10-07        2023-06-26
# 4           5             Basic               10 2023-01-05        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25        2023-12-07
# 2496     2497             Basic               15 2022-04-08        2023-07-14
# 2497     2498          Standard               12 2022-09-08        2023-07-15
# 2498     2499          Standard               13 2022-12-08        2023-12-07
# 2499     2500             Basic               15 2022-08-13        2023-12-07
#
# ...

# %%
df["Join Date"] = pd.to_datetime(df["Join Date"])
df["Last Paynent Date"] = pd.to_datetime(df["Last Payment Date"])

# %%
import pandas as pd
# Assuming "df" Is your DotaFrane with a 'Join Date* colum
df[ 'Join Date'] = pd.to_datetime(df['Join Date'])
# Extract month names
df['Join Month' ] = df['Join Date' ].dt.month_name()
#Dispiay the DotoFrome with the sdded "Join Month" coluen
print(df)
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15        2023-10-06
# 1           2           Premium               15 2021-05-09        2023-06-22
# 2           3          Standard               12 2023-02-28        2023-06-27
# 3           4          Standard               12 2022-10-07        2023-06-26
# 4           5             Basic               10 2023-01-05        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25        2023-12-07
# 2496     2497             Basic               15 2022-04-08        2023-07-14
# 2497     2498          Standard               12 2022-09-08        2023-07-15
# 2498     2499          Standard               13 2022-12-08        2023-12-07
# 2499     2500             Basic               15 2022-08-13        2023-12-07
#
# ...

# %%
Joining_Month_Count = df["Join Month"].value_counts()
Joining_Month_Count.plot(kind='bar')
plt.xlabel=('join month')
plt.ylabel=('Count')
plt.title("joining count by months")
# Out:
# Text(0.5, 1.0, 'joining count by months')

# %%
#Deriving some useful features using Lambda function
def get_continent(country):
#returns the continent of the given country 
    if country in ("Unlted States", "Canada", "Mexico"):
        return "North Amertca"
    if country in ("France", "Gersary", "United Kingdon", "Italy", "Spatn"):
        return "Europe"
    if country == "Brazil":
        return "South America"
    if country == "Australia":
        return "Australla"
    return "Arrica / Asia"

# %%
def get_age_class(age):
     
    return "kid" if age<11 \
    else "teen" if age < 18 \
    else "young" if age < 40 \
    else "senior" if age < 70 \
    else "Elderly"
df["Country"] = df["Country"].apply(lambda x: get_continent(x))
df["Age"] = df["Age"].apply(lambda x: get_age_class(x))

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="Age", hue = "Device")
plt.xlabel=('Age')
plt.ylabel=('Device')
plt.title('device used in by age group incountries')
plt.show()

# %%
plt.figure(figsize=(4,3))
sns.countplot(data=df, x="Age", hue = "Gender")
plt.xlabel=('Age')
plt.ylabel=('Gender')
plt.title('gender vice age distribution')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="Gender", hue = "Device")
plt.xlabel=('Gender')
plt.ylabel=('Device')
plt.title('device used according to gender')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="Gender", hue = "Subscription Type")
plt.xlabel=('Gender')
plt.ylabel=('Subscription Type')
plt.title('Subscription Type used according to gender')
plt.show()

# %%
#DataVisualization #Insights #Analytics Group the data by Feedback and calculate the count of each category
country =  df.groupby('Country').size()
#Create a pie chart
plt.figure(figsize=(4, 4))
plt.pie(country, labels = country.index, shadow=True,autopct='%1.1f%%', startangle=148) 
plt.title('subscription_across_continents')
plt.axis('equal') # Equal aspect ratio ensures that pie is drawn as a circle. 
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="Subscription Type", hue = "Country")
plt.xlabel=('Subscription Type')
plt.ylabel=('Country')
plt.title('Subscription Type used across continents')
plt.show()

# %%
plt.figure(figsize=(8,6))
sns.countplot(data=df, x="Subscription Type", hue = "Device")
plt.xlabel=('Subscription Type')
plt.ylabel=('Device')
plt.title('Subscription Type used across Devices')
plt.show()

# %%
df
# Out:
#       User ID Subscription Type  Monthly Revenue  Join Date Last Payment Date  \
# 0           1             Basic               10 2022-01-15        2023-10-06
# 1           2           Premium               15 2021-05-09        2023-06-22
# 2           3          Standard               12 2023-02-28        2023-06-27
# 3           4          Standard               12 2022-10-07        2023-06-26
# 4           5             Basic               10 2023-01-05        2023-06-28
# ...       ...               ...              ...        ...               ...
# 2495     2496           Premium               14 2022-07-25        2023-12-07
# 2496     2497             Basic               15 2022-04-08        2023-07-14
# 2497     2498          Standard               12 2022-09-08        2023-07-15
# 2498     2499          Standard               13 2022-12-08        2023-12-07
# 2499     2500             Basic               15 2022-08-13        2023-12-07
#
# ...

# %%
X = df.drop(columns=['Subscription Type','Join Date','Last Payment Date','Country'])
X
# Out:
#       User ID  Monthly Revenue     Age  Gender      Device Plan Duration  \
# 0           1               10   young    Male  Smartphone       1 Month
# 1           2               15   young  Female      Tablet       1 Month
# 2           3               12  senior    Male    Smart TV       1 Month
# 3           4               12  senior  Female      Laptop       1 Month
# 4           5               10   young    Male  Smartphone       1 Month
# ...       ...              ...     ...     ...         ...           ...
# 2495     2496               14   young  Female    Smart TV       1 Month
# 2496     2497               15   young  Female    Smart TV       1 Month
# 2497     2498               12   young    Male      Laptop       1 Month
# 2498     2499               13  senior  Female      Tablet       1 Month
# 2499     2500               15   young  Female    Smart TV       1 Month
#
#      Last Paynent Date Join Month
# 0           2023-10-06    January
# ...
